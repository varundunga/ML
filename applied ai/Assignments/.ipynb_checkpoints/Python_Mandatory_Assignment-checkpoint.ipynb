# %% [markdown]
# <h1>Python: without numpy or sklearn </h1>

# %% [markdown]
# <h3> Q1: Given two matrices please print the product of those two matrices </h3>
# <pre>
#
# Ex 1: A   = [[1 3 4]
#              [2 5 7]
#              [5 9 6]]
#       B   = [[1 0 0]
#              [0 1 0]
#              [0 0 1]]
#       A*B = [[1 3 4]
#              [2 5 7]
#              [5 9 6]]
#
#
# Ex 2: A   = [[1 2]
#              [3 4]]
#       B   = [[1 2 3 4 5]
#              [5 6 7 8 9]]
#       A*B = [[11 14 17 20 23]
#              [18 24 30 36 42]]
#
# Ex 3: A   = [[1 2]
#              [3 4]]
#       B   = [[1 4]
#              [5 6]
#              [7 8]
#              [9 6]]
#       A*B =Not possible
# </pre>

# %%
# write your python code here
# you can take the above example as sample input for your program to test
# it should work for any general input try not to hard code for only given input examples
# you can free to change all these codes/structure
# here A and B are list of lists

def output_matrix(mat):
    '''function to print output in matrix format'''
    if(type(mat)==str):
        print('Not Possible')
        return
    for i in mat:
        if(i!=mat[-1]):
            print('[{}\n'.format(i))
        else:
            print('{}]'.format(i))        
def input_to_matrix(mat):
    '''function to convert input to matrix format'''
    x=list(mat)
    lst=[]
    m=[]   
    for i in x:
        if(i==' '):
            continue
        elif(i==';'):
            m.append(lst)
            lst=[]
        else:
            try:
                lst.append(int(i))
            except:
                print('enter only numbers')
                m=[]
                lst=[]
                break
    if(len(m)==0 and len(lst)==0):
        return m
    m.append(lst)
    for i in m:
        if(len(i)!=len(m[0])):
            m=[]
            print('All rows should be of same size')
    return m        
def matrix_mul(A, B):
    '''function to do matrix multiplication'''
    X=input_to_matrix(A)
    if(len(X)==0):
        return ''
    Y=input_to_matrix(B)
    if(len(Y)==0):
        return ''
    if(len(X[0])!=len(Y)):
        return 'A*B not possible'
    result=[]    
    for row in X:
        lst=[]
        for col in zip(*Y):
            s=0
            for a,b in zip(row,col):
                s+=a*b                
            lst.append(s)
        result.append(lst)        
    return result
A=input('enter 1st matrix with each element separated by space and row separated by a ; //n')
B=input('enter 2nd matrix with each element separated by space and row separated by a ; //n')
print('A = ')
output_matrix(input_to_matrix(A))
print('B = ')
output_matrix(input_to_matrix(B))
print('A*B = ')
output_matrix(matrix_mul(A,B))
# Out:
# enter 1st matrix with each element separated by space and row separated by a ; //n1 2;3 4
# enter 2nd matrix with each element separated by space and row separated by a ; //n1 2 3 4 5;5 6 7 8 9
# A =
# [[1, 2]
#
# [3, 4]]
# B =
# [[1, 2, 3, 4, 5]
#
# [5, 6, 7, 8, 9]]
# A*B =
# [[11, 14, 17, 20, 23]
#
# [23, 30, 37, 44, 51]]

# %% [markdown]
# <h3> Q2: Select a number randomly with probability proportional to its magnitude from the given array of n elements</h3>
#
# consider an experiment, selecting an element from the list A randomly with probability proportional to its magnitude.
# assume we are doing the same experiment for 100 times with replacement, in each experiment you will print a number that is selected randomly from A.
#
# <pre>
# Ex 1: A = [0 5 27 6 13 28 100 45 10 79]
# let f(x) denote the number of times x getting selected in 100 experiments.
# f(100) > f(79) > f(45) > f(28) > f(27) > f(13) > f(10) > f(6) > f(5) > f(0)
# </pre>

# %%
import random as r
# # write your python code here
# # you can take the above example as sample input for your program to test
# # it should work for any general input try not to hard code for only given input examples


# you can free to change all these codes/structure
def probability_list(A):
    '''function to generate list of length 100 containing only numbers from 
    input with numbers being duplicated based on their magnitude'''
    m=[]
    for i in A:
        lst=[]
        lst.append(i)
        lst=lst*int((i/sum(A))*100)#duplicating the element in list based on its magnitude
        for j in lst:
            m.append(j)
    while(len(m)<100):
        m.append(max(A))
    return m
def pick_a_number_from_list(plist):
    '''function to return a random number from probability list and remove the element generated from list'''
    num=r.choice(plist)
    plist.remove(num)
    return num,plist
    
def sampling_based_on_magnitued(plist):
    '''function to print number randomly based on its magnitude in 100 experiments'''
    for i in range(1,100):
        number,plist = pick_a_number_from_list(plist)
        print(number,end=',')
A=list(map(lambda a: int(a),list(input('enter list of intergers with a space between each integer').split())))'''converting
input entries to list of integers'''
plist=probability_list(A)
sampling_based_on_magnitued(plist)

# sampling_based_on_magnitued()
# Out:
# enter list of intergers with a space between each integer1 4 5
# [5, 1, 1, 5, 5, 4, 5, 5, 4, 5, 4, 4, 5, 4, 4, 5, 1, 5, 5, 5, 1, 4, 4, 4, 5, 5, 5, 5, 1, 4, 5, 4, 5, 4, 5, 1, 4, 1, 5, 4, 4, 5, 4, 5, 5, 5, 1, 1, 4, 5, 5, 4, 4, 5, 4, 4, 5, 5, 4, 1, 4, 5, 5, 4, 4, 4, 4, 4, 5, 5, 4, 5, 5, 4, 5, 4, 5, 4, 5, 4, 5, 5, 4, 5, 5, 5, 4, 4, 5, 4, 1, 5, 4, 5, 5, 5, 5, 5, 4, 5]

# %% [markdown]
# <h3> Q3: Replace the digits in the string with #</h3>
#
# Consider a string that will have digits in that, we need to remove all the characters which are not digits and replace the digits with #
# <pre>
# Ex 1: A = 234                Output: ###
# Ex 2: A = a2b3c4             Output: ###
# Ex 3: A = abc                Output:   (empty string)
# Ex 5: A = #2a$#b%c%561#      Output: ####
# </pre>

# %%
import re
# write your python code here
# you can take the above example as sample input for your program to test
# it should work for any general input try not to hard code for only given input examples

# you can free to change all these codes/structure
# String: it will be the input to your program
def replace_digits(String):
    b=' '
    for i in range(0,len(String)):
        try:
            String[i]=int(String[i])
        except:
            continue
    lst=list(map(lambda x:'#',list(filter(lambda x: type(x)==int,String))))
    if(len(lst)>0):
        for i in lst:
            print(i,end='')
    else:
        print('')
String=list(input('enter the string'))
a=[1,2,3]
# print(str(a))
replace_digits(String)
# Out:
# enter the string#2a$#b%c%561#
# ####

# %% [markdown]
# <h3> Q4: Students marks dashboard</h3>
#
# Consider the marks list of class students given in two lists <br>
# Students = ['student1','student2','student3','student4','student5','student6','student7','student8','student9','student10'] <br>
# Marks = [45, 78, 12, 14, 48, 43, 45, 98, 35, 80] <br>
# from the above two lists the Student[0] got Marks[0],  Student[1] got Marks[1] and so on. <br><br>
#
# Your task is to print the name of students
#
# <strong>a. Who got top 5 ranks, in the descending order of marks</strong> <br>
# <strong>b. Who got least 5 ranks, in the increasing order of marks</strong><br>
# <strong>d. Who got marks between  &gt;25th percentile &lt;75th percentile, in the increasing order of marks.</strong>
#
# <pre>
# Ex 1:
# Students=['student1','student2','student3','student4','student5','student6','student7','student8','student9','student10']
# Marks = [45, 78, 12, 14, 48, 43, 47, 98, 35, 80]
#
# a.
# student8  98
# student10 80
# student2  78
# student5  48
# student7  47
#
# b.
# student3 12
# student4 14
# student9 35
# student6 43
# student1 45
#
# c.
# student9 35
# student6 43
# student1 45
# student7 47
# student5 48
# </pre>

# %%
# write your python code here
# you can take the above example as sample input for your program to test
# it should work for any general input try not to hard code for only given input examples

# you can free to change all these codes/structure
def display_dash_board(students, marks):
    lst=list(zip(students,marks))
    lst.sort(key= lambda x: x[1])
    print('Students with Top 5 ranks')
    for i in lst[::-1][0:5]:
        print('{0} {1}'.format(i[0],i[1]))
    print('Students with least 5 ranks')
    for i in lst[0:5]:
        print('{0} {1}'.format(i[0],i[1]))
    print('Who got marks between >25th percentile <75th percentile')
    for i in range(int(len(lst)*0.25),int(len(lst)*0.75)):
        print('{0} {1}'.format(lst[i][0],lst[i][1]))
students=list(input('enter the list of students separated by space').split())
if(len(students)<5):
    print('number of students less than 5')
    students=list(input('enter the list of students separated by space').split())
marks=list(map(lambda a:int(a),list(input('enter the list of marks separated by space').split())))
if(len(marks)!=len(students)):
    print('enter marks for all students')
    marks=list(map(lambda a:int(a),list(input('enter the list of marks separated by space').split())))
display_dash_board(students,marks)
# Out:
# enter the list of students separated by spacestudent1 student2 student3 student4 student5 student6 student7 student8 student9 student10
# enter the list of marks separated by space45 78 12 14 48 43 47 98 35 80
# Students with Top 5 ranks
# student8 98
# student10 80
# student2 78
# student5 48
# student7 47
# Students with least 5 ranks
# student3 12
# student4 14
# student9 35
# student6 43
# student1 45
# Who got marks between >25th percentile <75th percentile
# student9 35
# student6 43
# student1 45
# student7 47
# student5 48

# %% [markdown]
# <h3> Q5: Find the closest points</h3>
#
# Consider you are given n data points in the form of list of tuples like S=[(x1,y1),(x2,y2),(x3,y3),(x4,y4),(x5,y5),..,(xn,yn)] and a point P=(p,q) <br> your task is to find 5 closest points(based on cosine distance) in S from P
#
# <br>Cosine distance between two points (x,y) and (p,q) is defined as $cos^{-1}(\frac{(x\cdot p+y\cdot q)}{\sqrt(x^2+y^2)\cdot\sqrt(p^2+q^2)})$
# <pre>
# Ex:
#
# S= [(1,2),(3,4),(-1,1),(6,-7),(0, 6),(-5,-8),(-1,-1)(6,0),(1,-1)]
# P= (3,-4)
# <img src='https://i.imgur.com/vIFPOcG.jpg', width=300>
# Output:
# (6,-7)
# (1,-1)
# (6,0)
# (-5,-8)
# (-1,-1)
# </pre>

# %%
import math as m

# write your python code here
# you can take the above example as sample input for your program to test
# it should work for any general input try not to hard code for only given input examples
# you can free to change all these codes/structure
# here S is list of tuples and P is a tuple ot len=2
def closest_points_to_p(Stup,P):
    Stup=input_to_list(Stup)
    P=input_to_list(P)
    dst=[]
    for S in Stup:
        k=S[0]*P[0][0]+S[1]*P[0][1]
        l=((S[0]**2+S[1]**2)**0.5)*(P[0][0]**2+P[0][1]**2)**(0.5)
        dst.append(m.acos(k/l))
    k=list(zip(Stup,dst))
    k.sort(key= lambda x: x[1])
    for i in k[0:5]:
        print(i[0])
    
def input_to_list(A):
    '''function to convert input to list of lists'''
    A=A.replace('[','').replace('),',' ').replace(']','').replace('(','').replace(')','').split()
    B=[]
    for i in A:
        B.append(tuple(map(lambda a:int(a),i.split(','))))
    return B
# S=[(1,2),(3,4),(-1,1),(6,-7),(0,6),(-5,-8),(-1,-1),(6,0),(1,-1)]
S= input('enter list of tuples with no spaces')
P= input('enter the point as tuple with no spaces')
closest_points_to_p(S,P)
# Out:
# enter list of tuples with no spaces[(1,2),(3,4),(-1,1),(6,-7),(0,6),(-5,-8),(-1,-1),(6,0),(1,-1)]
# enter the point as tuple with no spaces(3,-4)
# (6, -7)
# (1, -1)
# (6, 0)
# (-5, -8)
# (-1, -1)

# %% [markdown]
# <h3> Q6: Find which line separates oranges and apples</h3>
#
# Consider you are given two set of data points in the form of list of tuples like
# <pre>
# Red =[(R11,R12),(R21,R22),(R31,R32),(R41,R42),(R51,R52),..,(Rn1,Rn2)]
# Blue=[(B11,B12),(B21,B22),(B31,B32),(B41,B42),(B51,B52),..,(Bm1,Bm2)]
# </pre>
# and set of line equations(in the string format, i.e list of strings)
# <pre>
# Lines = [a1x+b1y+c1,a2x+b2y+c2,a3x+b3y+c3,a4x+b4y+c4,..,K lines]
# Note: You need to do string parsing here and get the coefficients of x,y and intercept.
# </pre>
# Your task here is to print "YES"/"NO" for each line given. You should print YES, if all the red points are one side of the line and blue points are on other side of the line, otherwise you should print NO.
# <pre>
# Ex:
# Red= [(1,1),(2,1),(4,2),(2,4), (-1,4)]
# Blue= [(-2,-1),(-1,-2),(-3,-2),(-3,-1),(1,-3)]
# Lines=["1x+1y+0","1x-1y+0","1x+0y-3","0x+1y-0.5"]
# <img src='https://i.imgur.com/DoQf7mE.jpg' width=400>
# Output:
# YES
# NO
# NO
# YES
# </pre>

# %%
import math
# write your python code here
# you can take the above example as sample input for your program to test
# it should work for any general input try not to hard code for only given input strings
# you can free to change all these codes/structure
def dist(coef,points):
    return ((points[0]*coef[0])+(points[1]*coef[1])+coef[2])    
def i_am_the_one(Red,Blue,line):
    Red=input_to_list(Red)
    Blue=input_to_list(Blue)
    coef=list(map(lambda a:float(a),line.replace('x',',').replace('y',',').split(',')))
    reddists=[]
    bluedists=[]
    for r in Red:
        reddists.append(dist(coef,r)) 
    for b in Blue:
        bluedists.append(dist(coef,b))
    rm=list(filter(lambda a:a>0,reddists))
    bm=list(filter(lambda a:a>0,bluedists))
    if([len(rm),len(bm)]==[len(reddists),0] or [len(bm),len(rm)]==[len(bluedists),0] ):
        print('YES')
    else:
        print('NO')
def input_to_list(A):
    '''function to convert input to list of lists'''
    A=A.replace('[','').replace('),',' ').replace(']','').replace('(','').replace(')','').split()
    B=[]
    for i in A:
        B.append(tuple(map(lambda a:int(a),i.split(','))))
    return B
def lines_to_list(A):
    '''function to convert lines to list'''
    A=A.replace('[','').replace(']','').replace('"','').split(',')
    return A
Red= input('enter list of tuples with no spaces for Red')
Blue= input('enter list of tuples with no spaces for Blue')
Lines=input('enter a list of lines')
# Red= [(1,1),(2,1),(4,2),(2,4),(-1,4)]
# Blue= [(-2,-1),(-1,-2),(-3,-2),(-3,-1),(1,-3)]
# Lines=["1x+1y+0","1x-1y+0","1x+0y-3","0x+1y-0.5"]
Lines=lines_to_list(Lines)
for i in Lines:
    i_am_the_one(Red,Blue,i)
# Out:
# enter list of tuples with no spaces for Red[(1,1),(2,1),(4,2),(2,4),(-1,4)]
# enter list of tuples with no spaces for Blue[(-2,-1),(-1,-2),(-3,-2),(-3,-1),(1,-3)]
# enter a list of lines["1x+1y+0","1x-1y+0","1x+0y-3","0x+1y-0.5"]
# YES
# NO
# NO
# YES

# %% [markdown]
# <h3> Q7: Filling the missing values in the specified format</h3>
#
# You will be given a string with digits and '\_'(missing value) symbols you have to replace the '\_' symbols as explained
#
# <pre>
# Ex 1: _, _, _, 24 ==> 24/4, 24/4, 24/4, 24/4 i.e we. have distributed the 24 equally to all 4 places <br>
# Ex 2: 40, _, _, _, 60 ==> (60+40)/5,(60+40)/5,(60+40)/5,(60+40)/5,(60+40)/5 ==> 20, 20, 20, 20, 20 i.e. the sum of (60+40) is distributed qually to all 5 places<br>
# Ex 3: 80, _, _, _, _  ==> 80/5,80/5,80/5,80/5,80/5 ==> 16, 16, 16, 16, 16 i.e. the 80 is distributed qually to all 5 missing values that are right to it<br>
# Ex 4: _, _, 30, _, _, _, 50, _, _
# ==> we will fill the missing values from left to right
#     a. first we will distribute the 30 to left two missing values (10, 10, 10, _, _, _, 50, _, _)
#     b. now distribute the sum (10+50) missing values in between (10, 10, 12, 12, 12, 12, 12, _, _)
#     c. now we will distribute 12 to right side missing values (10, 10, 12, 12, 12, 12, 4, 4, 4)
# </pre>
# for a given string with comma seprate values, which will have both missing values numbers like ex: "_, _, x, _, _, _"
# you need fill the missing values
#
# Q: your program reads a string like ex: "_, _, x, _, _, _" and returns the filled sequence
#
# Ex:
# <pre>
# Input1: "_,_,_,24"
# Output1: 6,6,6,6
#
# Input2: "40,_,_,_,60"
# Output2: 20,20,20,20,20
#
# Input3: "80,_,_,_,_"
# Output3: 16,16,16,16,16
#
# Input4: "_,_,30,_,_,_,50,_,_"
# Output4: 10,10,12,12,12,12,4,4,4
# </pre>

# %%
# write your python code here
# you can take the above example as sample input for your program to test
# it should work for any general input try not to hard code for only given input strings
# you can free to change all these codes/structure
def curve_smoothing(A):
    A=input_to_list(A)
    index=[]
    for i in range(0,len(A)):
        if(A[i]!=0):
            index.append(i)
    su=0
    for i in range(0,len(index)):
        try:
            if(A[i]==0):
                su=(A[0]+A[index[i]])/len(A[0:index[i]+1])
                A[0:index[i]+1]=list(map(lambda a:int(su),A[0:index[i]+1]))
                su=0
            if(i<len(index)-1):
                su=(A[index[i]]+A[index[i+1]])/len(A[index[i]:index[i+1]+1])
                A[index[i]:index[i+1]+1]=list(map(lambda a:int(su),A[index[i]:index[i+1]+1]))
                su=0
            if(i==len(index)-1 and index[i]!=len(A)-1):
                su=(A[index[i]]+A[len(A)-1])/len(A[index[i]:len(A)])
                A[index[i]:len(A)]=list(map(lambda a:int(su),A[index[i]:len(A)]))
                su=0
        except e:
            print(e)
        print(A)
def input_to_list(A):
    '''function to convert input string to list of integers'''
    A=A.replace('_','0').split(',')
    A=list(map(lambda a:int(a),A))
    return A
A=input('enter the string')
curve_smoothing(A)
# Out:
# enter the string80,_,_,_,_
# [16, 16, 16, 16, 16]

# %% [markdown]
# <h3> Q8: Find the probabilities</h3>
#
# You will be given a list of lists, each sublist will be of length 2 i.e. [[x,y],[p,q],[l,m]..[r,s]]
# consider its like a martrix of n rows and two columns
# 1. The first column F will contain only 5 uniques values (F1, F2, F3, F4, F5)
# 2. The second column S will contain only 3 uniques values (S1, S2, S3)
# <pre>
# your task is to find
# a. Probability of P(F=F1|S==S1), P(F=F1|S==S2), P(F=F1|S==S3)
# b. Probability of P(F=F2|S==S1), P(F=F2|S==S2), P(F=F2|S==S3)
# c. Probability of P(F=F3|S==S1), P(F=F3|S==S2), P(F=F3|S==S3)
# d. Probability of P(F=F4|S==S1), P(F=F4|S==S2), P(F=F4|S==S3)
# e. Probability of P(F=F5|S==S1), P(F=F5|S==S2), P(F=F5|S==S3)
# </pre>
# Ex:
#
# <pre>
# [[F1,S1],[F2,S2],[F3,S3],[F1,S2],[F2,S3],[F3,S2],[F2,S1],[F4,S1],[F4,S3],[F5,S1]]
#
# a. P(F=F1|S==S1)=1/4, P(F=F1|S==S2)=1/3, P(F=F1|S==S3)=0/3
# b. P(F=F2|S==S1)=1/4, P(F=F2|S==S2)=1/3, P(F=F2|S==S3)=1/3
# c. P(F=F3|S==S1)=0/4, P(F=F3|S==S2)=1/3, P(F=F3|S==S3)=1/3
# d. P(F=F4|S==S1)=1/4, P(F=F4|S==S2)=0/3, P(F=F4|S==S3)=1/3
# e. P(F=F5|S==S1)=1/4, P(F=F5|S==S2)=0/3, P(F=F5|S==S3)=0/3
# </pre>

# %%
# write your python code here
# you can take the above example as sample input for your program to test
# it should work for any general input try not to hard code for only given input strings
# you can free to change all these codes/structure
def compute_conditional_probabilites(A):
    A=input_to_list(A)
    F=sorted(set(map(lambda a:a[0],A)))
    S=sorted(set(map(lambda a:a[1],A)))
    for f in F:
        for s in S:
            subset=[]
            for a in A:
                if(s in a):
                    subset.append(a)
            count=0
            for sub in subset:
                if(f in sub):
                    count+=1
            print('P(F={0}|S=={1})={2}/{3} '.format(f,s,count,len(subset)),end=' ')
        print('\n')
def input_to_list(A):
    '''function to convert input to list of lists'''
    A=A.replace('[','').replace('],',' ').replace(']','').split()
#     print(A)
    B=[]
    for i in A:
        B.append(i.split(','))
    return B
# A = [[F1,S1],[F2,S2],[F3,S3],[F1,S2],[F2,S3],[F3,S2],[F2,S1],[F4,S1],[F4,S3],[F5,S1]]
A=input('enter list of lists with no spaces')
compute_conditional_probabilites(A)
# Out:
# enter list of lists with no spaces[[F1,S1],[F2,S2],[F3,S3],[F1,S2],[F2,S3],[F3,S2],[F2,S1],[F4,S1],[F4,S3],[F5,S1]]
# P(F=F1|S==S1)=1/4  P(F=F1|S==S2)=1/3  P(F=F1|S==S3)=0/3
#
# P(F=F2|S==S1)=1/4  P(F=F2|S==S2)=1/3  P(F=F2|S==S3)=1/3
#
# P(F=F3|S==S1)=0/4  P(F=F3|S==S2)=1/3  P(F=F3|S==S3)=1/3
#
# P(F=F4|S==S1)=1/4  P(F=F4|S==S2)=0/3  P(F=F4|S==S3)=1/3
#
# P(F=F5|S==S1)=1/4  P(F=F5|S==S2)=0/3  P(F=F5|S==S3)=0/3

# %% [markdown]
# <h3> Q9: Operations on sentences </h3>
#
# You will be given two sentances S1, S2 your task is to find
# <pre>
# a. Number of common words between S1, S2
# b. Words in S1 but not in S2
# c. Words in S2 but not in S1
# </pre>
#
# Ex:
# <pre>
# S1= "the first column F will contain only 5 unique values"
# S2= "the second column S will contain only 3 unique values"
# Output:
# a. 7
# b. ['first','F','5']
# c. ['second','S','3']
# </pre>

# %%
# write your python code here
# you can take the above example as sample input for your program to test
# it should work for any general input try not to hard code for only given input strings
S1= set(input('enter the first sentence').split())
S2= set(input('enter the second sentence').split())
print(len(S1&S2))
print(list(S1-S2))
print(list(S2-S1))
# Out:
# enter the first sentencethe first column F will contain only 5 unique values
# enter the second sentencethe second column S will contain only 3 unique values
# 7
# ['F', '5', 'first']
# ['3', 'second', 'S']

# %% [markdown]
# <h3> Q10: Error Function</h3>
#
# You will be given a list of lists, each sublist will be of length 2 i.e. [[x,y],[p,q],[l,m]..[r,s]]
# consider its like a martrix of n rows and two columns
#
# a. the first column Y will contain interger values <br>
# b. the second column $Y_{score}$ will be having float values <br>
# Your task is to find the value of $f(Y,Y_{score}) = -1*\frac{1}{n}\Sigma_{for each Y,Y_{score} pair}(Ylog10(Y_{score})+(1-Y)log10(1-Y_{score}))$ here n is the number of rows in the matrix
# <pre>
# Ex:
# [[1, 0.4], [0, 0.5], [0, 0.9], [0, 0.3], [0, 0.6], [1, 0.1], [1, 0.9], [1, 0.8]]
# output:
# 0.44982
# </pre>
# $\frac{-1}{8}\cdot((1\cdot log_{10}(0.4)+0\cdot log_{10}(0.6))+(0\cdot log_{10}(0.5)+1\cdot log_{10}(0.5)) + ... + (1\cdot log_{10}(0.8)+0\cdot log_{10}(0.2)) )$

# %%
# write your python code here
# you can take the above example as sample input for your program to test
# it should work for any general input try not to hard code for only given input strings

import math as m
# you can free to change all these codes/structure
def compute_log_loss(A):
    lst=input_to_list(A)
    loss=0
    for i in lst:
        if(i[1]>=1 and i[1]<0):
            loss='Y_Score of all lists should be between 0 and 1 to calculate loss'
            break
        loss+=(i[0]*m.log10(i[1]))+(1-i[0])*m.log10((1-i[1]))
    if(type(loss)!=str):
        loss=-loss/len(lst)
    return loss
# A = [[1,0.4],[0,0.5],[0,0.9],[0,0.3],[0,0.6],[1,0.1],[1,0.9],[1,0.8]]
def input_to_list(A):
    '''function to convert input to list of lists'''
    A=A.replace('[','').replace('],',' ').replace(']','').split()
    B=[]
    for i in A:
        B.append(list(map(lambda a:float(a),i.split(','))))
    return B
A=input('enter list of lists with no spaces')
compute_log_loss(A)
# Out:
# enter list of lists with no spaces[[1,0.4],[0,0.5],[0,0.9],[0,0.3],[0,0.6],[1,0.1],[1,0.9],[1,0.8]]
# 0.42430993457031635
